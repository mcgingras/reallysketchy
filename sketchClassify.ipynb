# %%
import os, cv2, keras
import numpy as np
from keras.models import load_model

# %%
def classify(im):
    im_keras = im.reshape(1, 28, 28, 1)    
    keras_result = keras_model.predict(im_keras)[0]
    if keras_result[1] > keras_result[0]:
        return "chair"
    else:
        return "sofa"

def process(im):
    im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    im_final = cv2.resize(im_gray, (28, 28))
    
    return im_final

# %%
if __name__ == '__main__':
    keras_model = load_model('model_keras.h5')
    imagePath = "images/sofa0.png"
    image = cv2.imread(imagePath)
    im_process = process(image)
    result = classify(im_process)
    print(result)
# Out:
# sofa

# %% [markdown]
# # Testing

# %%
import os, sklearn, cv2, imageio
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import time, pickle
from scipy import misc
from sklearn.linear_model import LogisticRegression

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.models import load_model

# %%
def classify(im):
    im_lr = im.ravel()
    im_lr = im_lr.reshape(1, -1)
    
    im_keras = im.reshape(1, 28, 28, 1)
    
    lr_result = lr_model.predict_proba(im_lr)[0]
    keras_result = keras_model.predict(im_keras)[0]
    
#     if lr_result[1] > lr_result[0]:
#         print("Logistic Regression: chair")
#     else:
#         print("Logistic Regression: sofa")
    
    if keras_result[1] > keras_result[0]:
        print("Keras: chair")
    else:
        print("Keras: sofa")

# %%
def process(im):
    im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
#     im_blur = cv2.medianBlur(im_gray, 5)
#     edges = cv2.Canny(im_gray,10,200)
#     kernel = np.ones((3, 3), np.uint8)
#     dilated_image = cv2.dilate(edges,kernel,iterations=1)
#     im_resize = cv2.resize(dilated_image, (28, 28))
    im_resize = cv2.resize(im_gray, (28, 28))
    
    return im_resize

# %%
def implot(image):
    plt.imshow(image,cmap = 'gray')
    plt.show(image.any)

# %%
folderPath = "images/"
lr_model = pickle.load(open('lr_model_v2.sav', 'rb'))
keras_model = load_model('model_keras.h5')

for imagePath in os.listdir(folderPath):
    if imagePath.endswith(".png"):
        imagePath = folderPath + imagePath
        image = cv2.imread(imagePath)
        im_process = process(image)
        implot(im_process)
        classify(im_process)
# Out:
# Keras: chair
# Keras: sofa

# %% [markdown]
# # Testing

# %%
imagePath = 'images/sofa1.png'
image = cv2.imread(imagePath)
im_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
im_blur = cv2.medianBlur(im_gray, 5)
edges = cv2.Canny(im_blur,100,200)
kernel = np.ones((5, 5), np.uint8)
dilated_image = cv2.dilate(edges,kernel,iterations=1)
im_resize = cv2.resize(dilated_image, (28, 28))

# %%
imagePath = "images/chair1.png"
image = misc.imread(imagePath, mode="L")
im = cv2.resize(image, (28, 28))
plt.imshow(im, cmap="gray")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
plt.imshow(image, cmap="gray")

# %%
im_lr = im.ravel()
im_lr = im_lr.reshape(1, -1)
print(im_lr.shape)

im_keras = im.reshape(1, 28, 28, 1)
print(im_keras.shape)
# Out:
# (1, 784)
# (1, 28, 28, 1)

# %%
lr = pickle.load(open('lr_model.sav', 'rb'))
keras = load_model('model_keras.h5')

# %% [markdown]
# # Classify (1- chair; 0 - sofa)

# %%
lr_result = lr.predict_proba(im_lr)
print("Logistic Regression: ", lr_result)
# Out:
# Logistic Regression:  [[0. 1.]]

# %%
keras_result = keras.predict(im_keras)
print("Keras: ", keras_result)
# Out:
# Keras:  [[0.34360012 0.6563999 ]]
